# %%
input_img = 'women2.jpg'

# %%
# %run "age_and_gender.ipynb"
# Out:
#                      ( women , (42.0, 'year old') )

# %%
input_img = 'women3.jpg'

# %%
# %run "age_and_gender.ipynb"
# Out:
#                      ( women , (72.0, 'year old') )

# %%
input_img = 'men1.jpg'

# %%
# %run "age_and_gender.ipynb"
# Out:
#                      ( men , (33.0, 'year old') )

# %%
input_img = 'men2.jpg'

# %%
# %run "age_and_gender.ipynb"
# Out:
#                      ( men , (37.0, 'year old') )

# %%
input_img = 'men3.jpg'

# %%
# %run "age_and_gender.ipynb"
# Out:
#                      ( men , (56.0, 'year old') )

# %%
input_img = 'boy.jpg'

# %%
# %run "age_and_gender.ipynb"
# Out:
#                      ( men , (19.0, 'year old') )
